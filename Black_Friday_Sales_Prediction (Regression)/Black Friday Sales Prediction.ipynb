# %%
#Import necessary libraries
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#loading the dataset
df = pd.read_csv('train.csv')
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
#datset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
#statistical info
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# 25%              5.000000            9.000000    5823.000000
# 50%              9.000000           14.000000    8047.000000
# 75%             15.000000           16.000000   12054.000000
# max             18.000000           18.000000   23961.000000

# %%
#number of unique values
df.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               20
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      18105
# dtype: int64

# %%
#create a histplot for target
sns.histplot(data=df, x='Purchase', bins=25)
# Out:
# <Axes: xlabel='Purchase', ylabel='Count'>

# %%
sns.countplot(data=df, x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df, x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(data=df, x='Marital_Status')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(data=df, x='Occupation')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(data=df, x='Product_Category_1')
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(data=df, x='Product_Category_2')
# Out:
# <Axes: xlabel='Product_Category_2', ylabel='count'>

# %%
sns.countplot(data=df, x='Product_Category_3')
# Out:
# <Axes: xlabel='Product_Category_3', ylabel='count'>

# %%
sns.countplot(data=df, x='City_Category')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(data=df, x='Stay_In_Current_City_Years')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
#Occupation and purchase analysis
occupation_plot = df.pivot_table(index='Occupation', values='Purchase')
occupation_plot.plot(kind='bar', figsize=(14,7))
plt.ylabel('Purchase')
plt.xlabel('Occupation')
plt.title('Occupation and Purchase Analysis')
plt.show()

# %%
#Age and purchase analysis
age_plot = df.pivot_table(index='Age', values='Purchase')
age_plot.plot(kind='bar', figsize=(14,7))
plt.ylabel('Purchase')
plt.xlabel('Age')
plt.title('Age and Purchase Analysis')
plt.show()

# %%
#Gender and purchase analysis
Gender_plot = df.pivot_table(index='Gender', values='Purchase')
Gender_plot.plot(kind='bar', figsize=(14,7))
plt.ylabel('Purchase')
plt.xlabel('Gender')
plt.title('Gender and Purchase Analysis')
plt.show()

# %%
#checking null values
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
#filing them with mean
mean_value=df['Product_Category_2'].mean()
df['Product_Category_2'].fillna(mean_value, inplace=True)
df['Product_Category_3'].fillna(mean_value, inplace=True)
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
df.drop(columns=['User_ID','Product_ID'], inplace=True)

# %%
#Encoding using dict
gender_dict = {'F':0, 'M':1}
df['Gender'] = df['Gender'].apply(lambda x:gender_dict[x])

# %%
df.head()
# Out:
#    Gender   Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0       0  0-17          10             A                          2
# 1       0  0-17          10             A                          2
# 2       0  0-17          10             A                          2
# 3       0  0-17          10             A                          2
# 4       1   55+          16             C                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3            9.842329            9.842329
# 1               0                   1            6.000000           14.000000
# 2               0                  12            9.842329            9.842329
# 3               0                  12           14.000000            9.842329
# 4               0                   8            9.842329            9.842329
#
#    Purchase
# 0      8370
# 1     15200
# 2      1422
# 3      1057
# 4      7969

# %%
#Label Encoding
cols = ['Age', 'City_Category', 'Stay_In_Current_City_Years']
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for col in cols:
    df[col] = le.fit_transform(df[col])
df.head()
# Out:
#    Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0       0    0          10              0                           2
# 1       0    0          10              0                           2
# 2       0    0          10              0                           2
# 3       0    0          10              0                           2
# 4       1    6          16              2                           4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3            9.842329            9.842329
# 1               0                   1            6.000000           14.000000
# 2               0                  12            9.842329            9.842329
# 3               0                  12           14.000000            9.842329
# 4               0                   8            9.842329            9.842329
#
#    Purchase
# 0      8370
# 1     15200
# 2      1422
# 3      1057
# 4      7969

# %%
#Heat map
corr = df.corr()
plt.figure(figsize=(14,7))
sns.heatmap(corr, annot= True, cmap='coolwarm',)
# Out:
# <Axes: >

# %%
#Data split

X = df.drop(columns=['Purchase'])
y = df['Purchase']

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
def train(model, X, y):
    #train test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)
    
    #standardscaler
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    #model fit
    model.fit(X_train_scaled, y_train)
    
    #model prediction
    pred = model.predict(X_test_scaled)
    
    #crossvalidation
    cv_score = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    cv_score = np.abs(np.mean(cv_score))
                      
    #model report
                      
    print('Model Report')
    print('MSE:',np.sqrt(mean_squared_error(y_test, pred)))
    print('Cross Validation score:',np.sqrt(cv_score))

# %%
from sklearn.linear_model import LinearRegression
le = LinearRegression()
train(le, X, y)
coef = pd.Series(le.coef_, X.columns).sort_values()
coef.plot(kind = 'bar', title= 'Model coefficient')
# Out:
# Model Report
# MSE: 4668.482802432166
# Cross Validation score: 4668.661629943692
# <Axes: title={'center': 'Model coefficient'}>

# %%
from sklearn.tree import DecisionTreeRegressor
Dt = DecisionTreeRegressor()
train(Dt, X, y)
coef = pd.Series(Dt.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind = 'bar', title= 'feature_importances')
# Out:
# Model Report
# MSE: 3335.8463858805308
# Cross Validation score: 3337.692267458103
# <Axes: title={'center': 'feature_importances'}>

# %%
from sklearn.ensemble import RandomForestRegressor
Rf = RandomForestRegressor()
train(Rf, X, y)
coef = pd.Series(Rf.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind = 'bar', title= 'feature_importances')
# Out:
# Model Report
# MSE: 3044.853869787344
# Cross Validation score: 3051.645490556658
# <Axes: title={'center': 'feature_importances'}>

# %%
from sklearn.ensemble import ExtraTreesRegressor
Et = ExtraTreesRegressor(n_jobs=-1)
train(Et, X, y)
coef = pd.Series(Et.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind = 'bar', title= 'feature_importances')
# Out:
# Model Report
# MSE: 3172.121892709919
# Cross Validation score: 3175.7324245984087
# <Axes: title={'center': 'feature_importances'}>
